# %%
## A.Install libraries into our environment to be used for Manipulation of our data
# !pip install numpy
# !pip install pandas 
# !pip install matplotlib
# !pip install seaborn
# Out:
# Requirement already satisfied: numpy in c:\users\gifton\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: pandas in c:\users\gifton\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\gifton\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gifton\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gifton\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gifton\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\gifton\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\gifton\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gifton\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\gifton\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gifton\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\gifton\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\gifton\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\gifton\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\gifton\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gifton\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gifton\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\gifton\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: seaborn in c:\users\gifton\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\gifton\anaconda3\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\gifton\anaconda3\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\gifton\anaconda3\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gifton\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\gifton\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gifton\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\gifton\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\gifton\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\gifton\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gifton\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gifton\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gifton\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gifton\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\gifton\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
## A.Import libraries into our environment to be used for Manipulation of our data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## B. For Statistics Computation we'll install Special packages to enable us calculate some statistics
# !pip install scipy
# !pip install statsmodels

## SCIPY Library has advanced capabilities for Statistical and Mathematical Analysis while STATSMODELS allows to work with Statistical Models.
# Out:
# Requirement already satisfied: scipy in c:\users\gifton\anaconda3\lib\site-packages (1.13.1)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in c:\users\gifton\anaconda3\lib\site-packages (from scipy) (1.26.4)
# Requirement already satisfied: statsmodels in c:\users\gifton\anaconda3\lib\site-packages (0.14.2)
# Requirement already satisfied: numpy>=1.22.3 in c:\users\gifton\anaconda3\lib\site-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\gifton\anaconda3\lib\site-packages (from statsmodels) (1.13.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\gifton\anaconda3\lib\site-packages (from statsmodels) (2.2.2)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\gifton\anaconda3\lib\site-packages (from statsmodels) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in c:\users\gifton\anaconda3\lib\site-packages (from statsmodels) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gifton\anaconda3\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gifton\anaconda3\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gifton\anaconda3\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2023.3)
# Requirement already satisfied: six in c:\users\gifton\anaconda3\lib\site-packages (from patsy>=0.5.6->statsmodels) (1.16.0)

# %%
## Lets us import the newly installed packages into our environment
import scipy
import statsmodels.api as sm

# %%
## Lets us also import statistics library  into our environment
import statistics as stats

# %%
## Import our data into our environment
jobs_df = pd.read_csv(r"C:\Users\Gifton\Videos\0.0002 DATA ANALYTICS\2026, APRIL PROJECTS\103 PROJECT\job_salary_prediction_dataset.csv")
jobs_df
# Out:
#                  job_title  experience_years education_level  skills_count  \
# 0              AI Engineer                10        Bachelor             2
# 1             Data Analyst                 5        Bachelor            17
# 2       Frontend Developer                18             PhD             4
# 3         Business Analyst                19             PhD            13
# 4          Product Manager                15        Bachelor             7
# ...                    ...               ...             ...           ...
# 249995   Software Engineer                17             PhD             2
# 249996  Frontend Developer                20             PhD             7
# 249997    Business Analyst                 1        Bachelor            12
# 249998      Data Scientist                 0     High School             2
# 249999        Data Analyst                16         Diploma             2
#
#              industry company_size   location remote_work  certifications  \
# 0          Healthcare       Medium      India      Hybrid               2
# 1             Telecom        Small  Australia          No               0
# 2               Media       Medium  Singapore          No               1
# 3              Retail       Medium     Canada         Yes               0
# 4       Manufacturing        Large     Sweden         Yes               0
# ...               ...          ...        ...         ...             ...
# 249995        Telecom   Enterprise      India          No               1
# 249996        Telecom      Startup     Remote          No               2
# 249997         Retail   Enterprise      India         Yes               0
# 249998     Consulting        Small     Sweden      Hybrid               5
# 249999     Technology       Medium         UK          No               5
#
#         salary
# 0       109413
# 1        93764
# 2       148123
# 3       189123
# 4       165069
# ...        ...
# 249995  127791
# 249996  154593
# 249997   75988
# 249998   90467
# 249999  133084
#
# [250000 rows x 10 columns]

# %%
## Create A Copy of our Data Frame which we'll be using and refer to the Original Copy incase of Mistakes
jobs_df1 = jobs_df.copy()
jobs_df1
# Out:
#                  job_title  experience_years education_level  skills_count  \
# 0              AI Engineer                10        Bachelor             2
# 1             Data Analyst                 5        Bachelor            17
# 2       Frontend Developer                18             PhD             4
# 3         Business Analyst                19             PhD            13
# 4          Product Manager                15        Bachelor             7
# ...                    ...               ...             ...           ...
# 249995   Software Engineer                17             PhD             2
# 249996  Frontend Developer                20             PhD             7
# 249997    Business Analyst                 1        Bachelor            12
# 249998      Data Scientist                 0     High School             2
# 249999        Data Analyst                16         Diploma             2
#
#              industry company_size   location remote_work  certifications  \
# 0          Healthcare       Medium      India      Hybrid               2
# 1             Telecom        Small  Australia          No               0
# 2               Media       Medium  Singapore          No               1
# 3              Retail       Medium     Canada         Yes               0
# 4       Manufacturing        Large     Sweden         Yes               0
# ...               ...          ...        ...         ...             ...
# 249995        Telecom   Enterprise      India          No               1
# 249996        Telecom      Startup     Remote          No               2
# 249997         Retail   Enterprise      India         Yes               0
# 249998     Consulting        Small     Sweden      Hybrid               5
# 249999     Technology       Medium         UK          No               5
#
#         salary
# 0       109413
# 1        93764
# 2       148123
# 3       189123
# 4       165069
# ...        ...
# 249995  127791
# 249996  154593
# 249997   75988
# 249998   90467
# 249999  133084
#
# [250000 rows x 10 columns]

# %%
## Check for our column Names
jobs_df1.columns
# Out:
# Index(['job_title', 'experience_years', 'education_level', 'skills_count',
#        'industry', 'company_size', 'location', 'remote_work', 'certifications',
#        'salary'],
#       dtype='object')

# %%
## In this Notebook Project, we'll be mainly interested in Statistical Analysis and Computations
## Fist let us check for data types of our columns
jobs_df1.dtypes
# Out:
# job_title           object
# experience_years     int64
# education_level     object
# skills_count         int64
# industry            object
# company_size        object
# location            object
# remote_work         object
# certifications       int64
# salary               int64
# dtype: object

# %%
## Categorize Categorical and Numerical Columns Separately
numerical_cols = jobs_df1.select_dtypes(include = ['int64'])
categorical_cols = jobs_df1.select_dtypes(include =['object'])

# %%
## We Obtain DESCRIPTIVES for both Numerical and Categorical columns data types
numerical_stats = numerical_cols.describe()
numerical_stats
# Out:
#        experience_years   skills_count  certifications         salary
# count     250000.000000  250000.000000   250000.000000  250000.000000
# mean          10.005408       9.997812        2.491928  145718.080524
# std            6.060602       5.479288        1.706475   37407.952729
# min            0.000000       1.000000        0.000000   31867.000000
# 25%            5.000000       5.000000        1.000000  119358.000000
# 50%           10.000000      10.000000        2.000000  143453.000000
# 75%           15.000000      15.000000        4.000000  169492.000000
# max           20.000000      19.000000        5.000000  333046.000000

# %%
categorical_stats = categorical_cols.describe()
categorical_stats
# Out:
#                 job_title education_level industry company_size   location  \
# count              250000          250000   250000       250000     250000
# unique                 12               5       10            5         10
# top     Backend Developer          Master  Finance        Large  Australia
# freq                21125           50352    25393        50254      25258
#
#        remote_work
# count       250000
# unique           3
# top             No
# freq         83621

# %%
## Let us obtain More Information for the Salary column
## Compute the Average Employee Salary
avg_salary = jobs_df1['salary'].mean().round(0)
avg_salary
# Out:
# 145718.0

# %%
## What is the Maximum Employee Salary
max_salary = jobs_df1['salary'].max()
max_salary
# Out:
# 333046

# %%
## What is the Minimum Employee Salary
min_salary = jobs_df1['salary'].min()
min_salary
# Out:
# 31867

# %%
## What is the Interquartile Range of employee salary
IQR = max_salary - min_salary
IQR
# Out:
# 301179

# %%
## What is the standard deviation for the Average Employee Salary
salary_dev = jobs_df1['salary'].std()
salary_dev
# Out:
# 37407.95272924413

# %%
jobs_df1.columns
# Out:
# Index(['job_title', 'experience_years', 'education_level', 'skills_count',
#        'industry', 'company_size', 'location', 'remote_work', 'certifications',
#        'salary'],
#       dtype='object')

# %%
## STATISTICS COMPUTATION WITH SAMPLING
## The Objective : To compare how the AVERAGE JOB TITLE SALARY COMPARES WITH THE SAMPLES JOB TITLE SALARIES
## For the entire population (N)
jobs_df1_estimate = jobs_df1['salary'].mean()
jobs_df1_estimate
# Out:
# 145718.080524

# %%
## Sampling with Python: lETS simulate a random sample(n of 50 job titles)
sampled_jobs = jobs_df1.sample(n=50, replace=True, random_state=31208)
sampled_jobs
# Out:
#                         job_title  experience_years education_level  \
# 140903           Business Analyst                 4     High School
# 244563      Cybersecurity Analyst                14         Diploma
# 72914              Cloud Engineer                10     High School
# 154473      Cybersecurity Analyst                 9          Master
# 109237          Backend Developer                10        Bachelor
# 19804            Business Analyst                 0     High School
# 166136           Business Analyst                17         Diploma
# 191764                AI Engineer                17     High School
# 138590               Data Analyst                17          Master
# 210172             Cloud Engineer                 6        Bachelor
# 153610  Machine Learning Engineer                 3          Master
# 125406          Backend Developer                 4          Master
# 178814         Frontend Developer                19          Master
# 160910           Business Analyst                 0     High School
# 4093              DevOps Engineer                 7     High School
# 19373       Cybersecurity Analyst                 1     High School
# 10547                 AI Engineer                18         Diploma
# 145629            DevOps Engineer                15         Diploma
# 87124              Data Scientist                 9         Diploma
# 66430   Machine Learning Engineer                 1          Master
# 136025  Machine Learning Engineer                 7         Diploma
# 243500           Business Analyst                11          Master
# 228755  Machine Learning Engineer                 5     High School
# 27902           Software Engineer                 8         Diploma
# 51471           Software Engineer                 0     High School
# 15616             DevOps Engineer                 4     High School
# 110839          Software Engineer                 5          Master
# 173807         Frontend Developer                 8        Bachelor
# 213835             Data Scientist                 7     High School
# 202019  Machine Learning Engineer                12         Diploma
# 220849  Machine Learning Engineer                 5         Diploma
# 232786  Machine Learning Engineer                 8         Diploma
# 137379          Software Engineer                 9             PhD
# 73490              Data Scientist                17     High School
# 85516           Software Engineer                13     High School
# 14086       Cybersecurity Analyst                 6             PhD
# 199025  Machine Learning Engineer                17          Master
# 188844                AI Engineer                 2        Bachelor
# 247149            Product Manager                 0             PhD
# 187377             Cloud Engineer                 3         Diploma
# 64036           Backend Developer                10        Bachelor
# 105086                AI Engineer                 5          Master
# 180927          Software Engineer                 4          Master
# 144709          Backend Developer                 1         Diploma
# 112114         Frontend Developer                 1         Diploma
# 203448               Data Analyst                13     High School
# 155050         Frontend Developer                18         Diploma
# 162461          Software Engineer                 5     High School
# 19053              Cloud Engineer                15        Bachelor
# 86384           Software Engineer                13        Bachelor
#
#         skills_count       industry company_size     location remote_work  \
# 140903             8         Retail       Medium  Netherlands         Yes
# 244563             4          Media        Large       Remote      Hybrid
# 72914              3     Technology      Startup       Canada          No
# 154473             7     Government        Large    Australia          No
# 109237            17     Technology   Enterprise       Remote         Yes
# 19804              2        Finance   Enterprise       Sweden          No
# 166136            19        Telecom   Enterprise           UK         Yes
# 191764            19     Consulting        Small  Netherlands         Yes
# 138590             9          Media   Enterprise    Australia          No
# 210172            12     Healthcare      Startup           UK          No
# 153610            15     Government        Small    Australia      Hybrid
# 125406             9        Finance   Enterprise      Germany          No
# 178814             4     Technology        Small       Canada         Yes
# 160910            18     Healthcare       Medium       Canada      Hybrid
# 4093               6        Finance        Small      Germany          No
# 19373             13     Healthcare      Startup    Singapore         Yes
# 10547              2     Healthcare        Large      Germany      Hybrid
# 145629             9  Manufacturing   Enterprise           UK      Hybrid
# 87124             19        Telecom        Large          USA      Hybrid
# 66430             16          Media        Large       Sweden          No
# 136025            14        Finance       Medium    Singapore      Hybrid
# 243500            19         Retail      Startup    Singapore          No
# 228755             5  Manufacturing       Medium    Singapore      Hybrid
# 27902              8  Manufacturing      Startup       Sweden      Hybrid
# 51471              6  Manufacturing       Medium  Netherlands         Yes
# 15616              4        Finance        Small          USA          No
# 110839             5        Finance        Small          USA          No
# 173807            19      Education      Startup      Germany         Yes
# 213835            16          Media        Small    Australia          No
# 202019             4         Retail      Startup    Australia      Hybrid
# 220849             7         Retail       Medium    Australia          No
# 232786             9      Education      Startup           UK      Hybrid
# 137379             6          Media      Startup        India      Hybrid
# 73490              8     Healthcare       Medium    Singapore          No
# 85516             19     Technology        Small          USA         Yes
# 14086             13         Retail        Small    Singapore      Hybrid
# 199025             5     Technology      Startup    Singapore          No
# 188844            15     Healthcare   Enterprise       Canada         Yes
# 247149             9          Media        Small        India      Hybrid
# 187377            16     Healthcare        Large       Remote          No
# 64036             11         Retail      Startup    Singapore          No
# 105086            10          Media   Enterprise          USA      Hybrid
# 180927             7        Finance        Small    Singapore      Hybrid
# 144709             1  Manufacturing       Medium    Australia         Yes
# 112114             9     Healthcare        Small      Germany         Yes
# 203448             6        Finance        Small          USA         Yes
# 155050            16     Government       Medium       Sweden          No
# 162461             2  Manufacturing      Startup       Sweden      Hybrid
# 19053              8     Healthcare      Startup      Germany         Yes
# 86384             19     Consulting        Large           UK      Hybrid
#
#         certifications  salary
# 140903               3   93613
# 244563               4  150113
# 72914                5  131476
# 154473               1  154539
# 109237               3  163928
# 19804                1   75580
# 166136               3  192875
# 191764               0  167224
# 138590               5  159027
# 210172               3  136309
# 153610               1  141465
# 125406               0  156341
# 178814               5  176239
# 160910               4   91135
# 4093                 2  126005
# 19373                4  104213
# 10547                4  195670
# 145629               2  186666
# 87124                5  191700
# 66430                4  170101
# 136025               1  135778
# 243500               1  113030
# 228755               0  109756
# 27902                4  104251
# 51471                4  109352
# 15616                0  131705
# 110839               1  150899
# 173807               2  121566
# 213835               2  109361
# 202019               2  124628
# 220849               0  118553
# 232786               4  142952
# 137379               4   87922
# 73490                4  138295
# 85516                3  172539
# 14086                3  138698
# 199025               5  156114
# 188844               3  215003
# 247149               1   95890
# 187377               0  134960
# 64036                5  113412
# 105086               4  241051
# 180927               2  109145
# 144709               4   91755
# 112114               2  100862
# 203448               4  132955
# 155050               5  139671
# 162461               1   86517
# 19053                1  154018
# 86384                2  174886

# %%
## Check for any rows that might have been duplicated
sampled_jobs.duplicated()
## Result: There are no duplicates
# Out:
# 140903    False
# 244563    False
# 72914     False
# 154473    False
# 109237    False
# 19804     False
# 166136    False
# 191764    False
# 138590    False
# 210172    False
# 153610    False
# 125406    False
# 178814    False
# 160910    False
# 4093      False
# 19373     False
# 10547     False
# 145629    False
# 87124     False
# 66430     False
# 136025    False
# 243500    False
# 228755    False
# 27902     False
# 51471     False
# 15616     False
# 110839    False
# 173807    False
# 213835    False
# 202019    False
# 220849    False
# 232786    False
# 137379    False
# 73490     False
# 85516     False
# 14086     False
# 199025    False
# 188844    False
# 247149    False
# 187377    False
# 64036     False
# 105086    False
# 180927    False
# 144709    False
# 112114    False
# 203448    False
# 155050    False
# 162461    False
# 19053     False
# 86384     False
# dtype: bool

# %%
## Part1. Compute the MEAN SALARY for the Sampled Jobs and AS Estimate_1 Variable
Estimate_1 = sampled_jobs['salary'].mean()
Estimate_1
# Out:
# 138394.86

# %%
## Part2. Generate a new sample of 50 jobs as Estimate_2 and compute the Mean(). Case using  a different random number say 56800
Estimate_2 = jobs_df1['salary'].sample(n=50, replace=True, random_state=56800).mean()
Estimate_2
# Out:
# 145028.5

# %%
## Part3. Compute a sampling distributions with 10,000 samples of 50 Job Titles and compute the Mean
estimate_list= []
for i in range(10000):
    estimate_list.append(jobs_df1['salary'].sample(n=50, replace=True).mean())

estimate_df = pd.DataFrame(data={'estimate':estimate_list}).mean()
estimate_df

## Result explanation: When using The POPULATION SALARY MEAN OF(145718) is almost identical to the Sampling Distribution SALARY MEAN OF(145674)
# Out:
# estimate    145674.12461
# dtype: float64

# %%
## Visualize Data to Show the Distribution of the:[MEAN POPULATION SALARY VS THE SAMPLING DISTRIBUTION MEAN SALARY]
## 1. Sampling Distribution Plot Visualization

plt.figure(figsize=(12,8))
sns.kdeplot(estimate_list, label='Sampled Jobs-Salary Distribution', 
            linewidth=2.5, fill=True, color='black', shade=True, alpha=0.3)
plt.legend()
plt.show()
# Out:
# C:\Users\Gifton\AppData\Local\Temp\ipykernel_4764\1295581313.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(estimate_list, label='Sampled Jobs-Salary Distribution',

# %%
## Visualize Data to Show the Distribution of the:[MEAN POPULATION SALARY VS THE SAMPLING DISTRIBUTION MEAN SALARY]
## 2. The Entire Population Visual Plots
plt.figure(figsize=(12,8))
sns.kdeplot(jobs_df1['salary'], label='Population Jobs-Salary Distribution', 
            linewidth=2.5, color='red', shade=True, alpha=0.3)
plt.legend()
plt.show()

## Result: The Sampling Distribution mirrors and is very identical to the Actual Population distribution. They both exhibit a Normal Distribution curve.
# Out:
# C:\Users\Gifton\AppData\Local\Temp\ipykernel_4764\2444313384.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(jobs_df1['salary'], label='Population Jobs-Salary Distribution',

# %%
## Sampling with Python: lETS simulate a random sample(n of 50 job titles)
sampled_jobs = jobs_df1.sample(n=50, replace=True, random_state=31208)
sampled_jobs
# Out:
#                         job_title  experience_years education_level  \
# 140903           Business Analyst                 4     High School
# 244563      Cybersecurity Analyst                14         Diploma
# 72914              Cloud Engineer                10     High School
# 154473      Cybersecurity Analyst                 9          Master
# 109237          Backend Developer                10        Bachelor
# 19804            Business Analyst                 0     High School
# 166136           Business Analyst                17         Diploma
# 191764                AI Engineer                17     High School
# 138590               Data Analyst                17          Master
# 210172             Cloud Engineer                 6        Bachelor
# 153610  Machine Learning Engineer                 3          Master
# 125406          Backend Developer                 4          Master
# 178814         Frontend Developer                19          Master
# 160910           Business Analyst                 0     High School
# 4093              DevOps Engineer                 7     High School
# 19373       Cybersecurity Analyst                 1     High School
# 10547                 AI Engineer                18         Diploma
# 145629            DevOps Engineer                15         Diploma
# 87124              Data Scientist                 9         Diploma
# 66430   Machine Learning Engineer                 1          Master
# 136025  Machine Learning Engineer                 7         Diploma
# 243500           Business Analyst                11          Master
# 228755  Machine Learning Engineer                 5     High School
# 27902           Software Engineer                 8         Diploma
# 51471           Software Engineer                 0     High School
# 15616             DevOps Engineer                 4     High School
# 110839          Software Engineer                 5          Master
# 173807         Frontend Developer                 8        Bachelor
# 213835             Data Scientist                 7     High School
# 202019  Machine Learning Engineer                12         Diploma
# 220849  Machine Learning Engineer                 5         Diploma
# 232786  Machine Learning Engineer                 8         Diploma
# 137379          Software Engineer                 9             PhD
# 73490              Data Scientist                17     High School
# 85516           Software Engineer                13     High School
# 14086       Cybersecurity Analyst                 6             PhD
# 199025  Machine Learning Engineer                17          Master
# 188844                AI Engineer                 2        Bachelor
# 247149            Product Manager                 0             PhD
# 187377             Cloud Engineer                 3         Diploma
# 64036           Backend Developer                10        Bachelor
# 105086                AI Engineer                 5          Master
# 180927          Software Engineer                 4          Master
# 144709          Backend Developer                 1         Diploma
# 112114         Frontend Developer                 1         Diploma
# 203448               Data Analyst                13     High School
# 155050         Frontend Developer                18         Diploma
# 162461          Software Engineer                 5     High School
# 19053              Cloud Engineer                15        Bachelor
# 86384           Software Engineer                13        Bachelor
#
#         skills_count       industry company_size     location remote_work  \
# 140903             8         Retail       Medium  Netherlands         Yes
# 244563             4          Media        Large       Remote      Hybrid
# 72914              3     Technology      Startup       Canada          No
# 154473             7     Government        Large    Australia          No
# 109237            17     Technology   Enterprise       Remote         Yes
# 19804              2        Finance   Enterprise       Sweden          No
# 166136            19        Telecom   Enterprise           UK         Yes
# 191764            19     Consulting        Small  Netherlands         Yes
# 138590             9          Media   Enterprise    Australia          No
# 210172            12     Healthcare      Startup           UK          No
# 153610            15     Government        Small    Australia      Hybrid
# 125406             9        Finance   Enterprise      Germany          No
# 178814             4     Technology        Small       Canada         Yes
# 160910            18     Healthcare       Medium       Canada      Hybrid
# 4093               6        Finance        Small      Germany          No
# 19373             13     Healthcare      Startup    Singapore         Yes
# 10547              2     Healthcare        Large      Germany      Hybrid
# 145629             9  Manufacturing   Enterprise           UK      Hybrid
# 87124             19        Telecom        Large          USA      Hybrid
# 66430             16          Media        Large       Sweden          No
# 136025            14        Finance       Medium    Singapore      Hybrid
# 243500            19         Retail      Startup    Singapore          No
# 228755             5  Manufacturing       Medium    Singapore      Hybrid
# 27902              8  Manufacturing      Startup       Sweden      Hybrid
# 51471              6  Manufacturing       Medium  Netherlands         Yes
# 15616              4        Finance        Small          USA          No
# 110839             5        Finance        Small          USA          No
# 173807            19      Education      Startup      Germany         Yes
# 213835            16          Media        Small    Australia          No
# 202019             4         Retail      Startup    Australia      Hybrid
# 220849             7         Retail       Medium    Australia          No
# 232786             9      Education      Startup           UK      Hybrid
# 137379             6          Media      Startup        India      Hybrid
# 73490              8     Healthcare       Medium    Singapore          No
# 85516             19     Technology        Small          USA         Yes
# 14086             13         Retail        Small    Singapore      Hybrid
# 199025             5     Technology      Startup    Singapore          No
# 188844            15     Healthcare   Enterprise       Canada         Yes
# 247149             9          Media        Small        India      Hybrid
# 187377            16     Healthcare        Large       Remote          No
# 64036             11         Retail      Startup    Singapore          No
# 105086            10          Media   Enterprise          USA      Hybrid
# 180927             7        Finance        Small    Singapore      Hybrid
# 144709             1  Manufacturing       Medium    Australia         Yes
# 112114             9     Healthcare        Small      Germany         Yes
# 203448             6        Finance        Small          USA         Yes
# 155050            16     Government       Medium       Sweden          No
# 162461             2  Manufacturing      Startup       Sweden      Hybrid
# 19053              8     Healthcare      Startup      Germany         Yes
# 86384             19     Consulting        Large           UK      Hybrid
#
#         certifications  salary
# 140903               3   93613
# 244563               4  150113
# 72914                5  131476
# 154473               1  154539
# 109237               3  163928
# 19804                1   75580
# 166136               3  192875
# 191764               0  167224
# 138590               5  159027
# 210172               3  136309
# 153610               1  141465
# 125406               0  156341
# 178814               5  176239
# 160910               4   91135
# 4093                 2  126005
# 19373                4  104213
# 10547                4  195670
# 145629               2  186666
# 87124                5  191700
# 66430                4  170101
# 136025               1  135778
# 243500               1  113030
# 228755               0  109756
# 27902                4  104251
# 51471                4  109352
# 15616                0  131705
# 110839               1  150899
# 173807               2  121566
# 213835               2  109361
# 202019               2  124628
# 220849               0  118553
# 232786               4  142952
# 137379               4   87922
# 73490                4  138295
# 85516                3  172539
# 14086                3  138698
# 199025               5  156114
# 188844               3  215003
# 247149               1   95890
# 187377               0  134960
# 64036                5  113412
# 105086               4  241051
# 180927               2  109145
# 144709               4   91755
# 112114               2  100862
# 203448               4  132955
# 155050               5  139671
# 162461               1   86517
# 19053                1  154018
# 86384                2  174886

# %%
## CALCULATING CONFIDENCE INTERVALS FOR OUR VERY FIRST SAMPLE (n=50 and random_state as 31208)
## Lets again calculate the Mean Job salary for the svery FIRST SAMPLED DATA and store it as an Estimate_mean variable
Estimate_1 = sampled_jobs['salary'].mean()
Estimate_1
# Out:
# 138394.86

# %%
## Import STATS library for Confidence Interval calculations
import scipy.stats as stats

# %%
## Create a New Variable to first calculate the estimated standard error
estimated_standard_error=sampled_jobs['salary'].std(ddof=1)/np.sqrt(sampled_jobs.shape[0])
estimated_standard_error
# Out:
# 5074.155938254406

# %%
## Then we CONSTRUCT A 95% Confidence Interval
confidence_interval = stats.norm.interval(confidence=0.95, loc=Estimate_1, scale=estimated_standard_error)
confidence_interval

    #The Estimate_1 is the n=50 Random Samples
# Out:
# (128449.6971090813, 148340.02289091866)

# %%
## Construct a 99% confidence interval for our Sample Job Salary Data
confidence_interval = stats.norm.interval(confidence=0.99, loc=Estimate_1, scale=estimated_standard_error)
confidence_interval

    #Explanation: On comparison of the two Confidence Intervals, as the Level increases so does the Interval gets even wider. They help Show how jobs salaries are distributed across the spectrum.
# Out:
# (125324.70044346762, 151465.01955653235)
